# %%
# Dependencies and Setup
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import numpy as np

# %%
# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)
mouseid_mouse_metadata = mouse_metadata.sort_values("Mouse ID")
#mouseid_mouse_metadata.head(5)

# %%
mouseid_study_results =study_results.sort_values("Mouse ID")
#mouseid_study_results.head(20)

# %%
# Combine the data into a single dataset
study_data_complete = pd.merge(mouseid_study_results, mouseid_mouse_metadata, how = 'left', on="Mouse ID")
#study_data_complete.head(10)

# %%
d= pd.DataFrame(study_data_complete).set_index('Mouse ID') 
dx = d.set_index('Timepoint')
df = pd.DataFrame(study_data_complete).set_index('Drug Regimen')
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# Mouse ID
# a203              0           45.000000                 0    Infubinol
# a203              5           48.508468                 0    Infubinol
# a203             25           56.793208                 1    Infubinol
# a203             40           63.593490                 2    Infubinol
# a203             35           61.931650                 2    Infubinol
# ...             ...                 ...               ...          ...
# z969             25           63.145652                 2     Naftisol
# z969             20           57.898778                 2     Naftisol
# z969              5           49.332999                 0     Naftisol
# z969             35           69.176246                 4     Naftisol
# z969             15           54.713005                 2     Naftisol
#
#              Sex  Age_months  Weight (g)
# Mouse ID
# a203      Female          20          23
# ...

# %%
s185 = pd.DataFrame(d.loc["s185","Tumor Volume (mm3)"])
s185
# Out:
#           Tumor Volume (mm3)
# Mouse ID
# s185               45.000000
# s185               38.177232
# s185               23.343598
# s185               43.878496
# s185               28.328531
# s185               37.614948
# s185               36.866876
# s185               32.959671
# s185               33.949940
# s185               25.472143

# %%
Capomulin_tumor = df.loc["Capomulin","Tumor Volume (mm3)"]
capomulin_weight = df.loc["Capomulin","Weight (g)"]
Capomulin_tumor_var = np.var(Capomulin,ddof = 0)
Capomulin_tumor_mode = sts.mode(Capomulin)
Capomulin_tumor_std = np.std(Capomulin, ddof = 0)
capomulin_weight
# Out:
# Drug Regimen
# Capomulin    22
# Capomulin    22
# Capomulin    22
# Capomulin    22
# Capomulin    22
#              ..
# Capomulin    17
# Capomulin    17
# Capomulin    17
# Capomulin    17
# Capomulin    17
# Name: Weight (g), Length: 230, dtype: int64

# %%
Ceftamin = df.loc["Ceftamin","Tumor Volume (mm3)"]
Ceftamin_tumor_var = np.var(Ceftamin,ddof = 0)
Ceftamin_tumor_mode = sts.mode(Ceftamin)
Ceftamin_tumor_std = np.std(Ceftamin, ddof = 0)

# %%
Infubinol = df.loc["Infubinol","Tumor Volume (mm3)"]
Infubinol_tumor_var = np.var(Infubinol,ddof = 0)
Infubinol_tumor_mode = sts.mode(Infubinol)
Infubinol_tumor_std = np.std(Infubinol, ddof = 0)

# %%
Ketapril = df.loc["Ketapril","Tumor Volume (mm3)"]
Ketapril_tumor_var = np.var(Ketapril,ddof = 0)
Ketapril_tumor_mode = sts.mode(Ketapril)
Ketapril_tumor_std = np.std(Ketapril, ddof = 0)

# %%
Naftisol = df.loc["Naftisol","Tumor Volume (mm3)"]
Naftisol_tumor_var = np.var(Naftisol,ddof = 0)
Naftisol_tumor_mode = sts.mode(Naftisol)
Naftisol_tumor_std = np.std(Naftisol, ddof = 0)

# %%
Placebo = df.loc["Placebo","Tumor Volume (mm3)"]
Placebo_tumor_var = np.var(Placebo,ddof = 0)
Placebo_tumor_mode = sts.mode(Placebo)
Placebo_tumor_std = np.std(Placebo, ddof = 0)

# %%
Propriva = df.loc["Propriva","Tumor Volume (mm3)"].mean()
Propriva_tumor_var = np.var(Propriva,ddof = 0)
Propriva_tumor_mode = sts.mode(Propriva)
Propriva_tumor_std = np.std(Propriva, ddof = 0)

# %%
Ramicane = df.loc["Ramicane","Tumor Volume (mm3)"].mean()
Ramicane_tumor_var = np.var(Ramicane,ddof = 0)
Ramicane_tumor_mode = sts.mode(Ramicane)
Ramicane_tumor_std = np.std(Ramicane, ddof = 0)

# %%
Stelasyn = df.loc["Stelasyn","Tumor Volume (mm3)"]
Stelasyn_tumor_var = np.var(Stelasyn,ddof = 0)
Stelasyn_tumor_mode = sts.mode(Stelasyn)
Stelasyn_tumor_std = np.std(Stelasyn, ddof = 0)

# %%
Zoniferol_float = float(df.loc["Zoniferol","Tumor Volume (mm3)"].mean())
Zoniferol = df.loc["Zoniferol","Tumor Volume (mm3)"].mean()
Zoniferol_tumor_var = np.var(Zoniferol,ddof = 0)
Zoniferol_tumor_mode = sts.mode(Zoniferol)
Zoniferol_tumor_std = np.std(Zoniferol, ddof = 0)
Zoniferol_tumor_var
Zoniferol_float
# Out:
# 53.23650655159343

# %%
sortby_time= study_data_complete.groupby("Timepoint").mean()
#sortby_time

# %%
new_df = pd.DataFrame({"Zoniferol": Zoniferol_float})
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-83a6d569c8b4> in <module>
# ----> 1 new_df = pd.DataFrame({"Zoniferol": Zoniferol_float})
#       2 new_df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ...

# %%
groupby_regimen = study_data_complete.groupby(['Drug Regimen'])
regimen_average_study_data_complete = study_data_complete.groupby(['Drug Regimen']).mean()
tumor_regimen_average_study_data_complete = regimen_average_study_data_complete['Tumor Volume (mm3)']
tumor_regimen_average_study_data_complete
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.322552
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
xx = study_data_complete['Sex']
sex_count = xx.value_counts()
#sex_count

# %%
regimen_median_study_data_complete = study_data_complete.groupby(['Drug Regimen']).median()
tumor_regimen_median_study_data_complete = regimen_median_study_data_complete['Tumor Volume (mm3)']
#tumor_regimen_median_study_data_complete

# %%
var_numpy_tumor = np.var(study_data_complete['Tumor Volume (mm3)'],ddof = 0)
#var_numpy_tumor

# %%
mode_scipy = sts.mode(study_data_complete['Tumor Volume (mm3)'])
#mode_scipy

# %%
sd_numpy_tumor = np.std(study_data_complete['Tumor Volume (mm3)'],ddof = 0)
#sd_numpy_tumor

# %%
count = groupby_regimen['Drug Regimen'].count()
drug_regimen_count =groupby_regimen['Drug Regimen'].count().count()
#count

# %%
summary = pd.DataFrame({"Number of Data Points":count,
                                   "Average Tumor Size":tumor_regimen_average_study_data_complete,
                       "Median Tumor Size":tumor_regimen_median_study_data_complete,"Zoniferol Tumor var": Zoniferol_tumor_var})
summary
# Out:
#               Number of Data Points  Average Tumor Size  Median Tumor Size  \
# Drug Regimen
# Capomulin                       230           40.675741          41.557809
# Ceftamin                        178           52.591172          51.776157
# Infubinol                       178           52.884795          51.820584
# Ketapril                        188           55.235638          53.698743
# Naftisol                        186           54.331565          52.509285
# Placebo                         181           54.033581          52.288934
# Propriva                        161           52.322552          50.854632
# Ramicane                        228           40.216745          40.673236
# Stelasyn                        181           54.233149          52.431737
# Zoniferol                       182           53.236507          51.818479
#
#               Zoniferol Tumor var
# Drug Regimen
# Capomulin               48.266689
# Ceftamin                48.266689
# ...

# %%
x_axis = np.arange(int(drug_regimen_count))

plt.title("Data Points Per Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Data Points")

plt.xlim(-0.75, int(drug_regimen_count))
plt.ylim(0, max(count) + 5)

plt.bar(x_axis, count, facecolor="red", alpha=.75, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"])


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Sex = ["Male", "Female"]
colors = ["blue","red",]
explode = (0.1,0)
plt.pie(sex_count, labels= Sex, colors=colors,
        autopct="%1.1f%%", explode = explode, shadow=True, startangle=140)
plt.title("Male to Female")
plt.axis("equal")
plt.savefig("Images/PyPies.png")
plt.show()

# %%
mice = pd.DataFrame({"Tumor Size by Mouse":tumor_groupby_mouse})
mice
# Out:
#           Tumor Size by Mouse
# Mouse ID
# a203               563.127077
# a251               552.370946
# a262               586.116306
# a275               527.709651
# a366               382.479341
# ...                       ...
# z435               140.826641
# z578               384.115100
# z581               539.795837
# z795               548.803167
# z969               601.946523
#
# [249 rows x 1 columns]

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. 
#Calculate the IQR and quantitatively determine
#if there are any potential outliers. 

fig1, ax1 = plt.subplots()
ax1.set_title('Tumor Volume By Mouse')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(mice)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
quartiles = mice.quantile([0.25, 0.5, 0.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Tumor Size is: {lowerq}")
print(f"The upper quartile of Tumor Size is: {upperq}")
print(f"The interquartile range of Tumor Sizeis: {iqr}")
print(f"The the median of Tumor Size is: {quartiles[.5]} ")

# %%
# Generate a box plot of the final tumor volume 
#of each mouse across four regimens of interest

# %%
fig1, ax1 = plt.subplots()
xaxis = s185[0]
yaxis = s185[1]
ax1.set_title("Mouse s185")
ax1.set_ylabel('Tumor Volume (mm3)')
plt.plot(s185)
plt.show()
# Out:
# <div id='61dc3955-b818-4878-a356-afc2a9a86622'></div>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-a792f8d1ca08> in <module>
# ...

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
fig1, ax1 = plt.subplots()
xaxis = capomulin_weight
yaxis = Capomulin_tumor
ax1.set_title("weight")
ax1.set_ylabel('tumor volume')

plt.scatter(xaxis, yaxis)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
